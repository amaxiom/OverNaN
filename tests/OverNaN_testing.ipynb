# %%
"""
Test suite for the OverNaN package.

Tests SMOTE, ADASYN, and ROSE algorithms with NaN-aware oversampling.
Includes unit tests, integration tests with classifiers, and edge case handling.
"""

# %run -i OverNaN_test.py
# Out:
# ######################################################################
# #                    OverNaN v0.2.0 Test Suite                   #
# ######################################################################
# ======================================================================
# TESTING BASIC FUNCTIONALITY
# ======================================================================
#
# Original data shape: (120, 10)
# Original class distribution: {0.0: 100, 1.0: 20}
# NaN percentage: 20.17%
#
# --------------------------------------------------
# Testing SMOTE with NaN handling
# --------------------------------------------------
# After SMOTE shape: (200, 10)
# After SMOTE class distribution: {0.0: 100, 1.0: 100}
# NaN percentage after SMOTE: 27.80%
#
# --------------------------------------------------
# Testing ADASYN with NaN handling
# --------------------------------------------------
# After ADASYN shape: (200, 10)
# After ADASYN class distribution: {0.0: 100, 1.0: 100}
# NaN percentage after ADASYN: 32.45%
#
# --------------------------------------------------
# Testing ROSE with NaN handling
# --------------------------------------------------
# After ROSE shape: (200, 10)
# After ROSE class distribution: {0.0: 100, 1.0: 100}
# NaN percentage after ROSE: 20.35%
#
# ======================================================================
# TESTING SAMPLING STRATEGIES
# ======================================================================
#
# --- Sampling strategy: auto ---
#   SMOTE   : {0.0: 100, 1.0: 100}
#   ADASYN  : {0.0: 100, 1.0: 100}
#   ROSE    : {0.0: 100, 1.0: 100}
#
# --- Sampling strategy: minority ---
#   SMOTE   : {0.0: 100, 1.0: 100}
#   ADASYN  : {0.0: 100, 1.0: 100}
#   ROSE    : {0.0: 100, 1.0: 100}
#
# --- Sampling strategy: not majority ---
#   SMOTE   : {0.0: 100, 1.0: 100}
#   ADASYN  : {0.0: 100, 1.0: 100}
#   ROSE    : {0.0: 100, 1.0: 100}
#
# --- Sampling strategy: 0.5 ---
#   SMOTE   : {0.0: 100, 1.0: 50}
#   ADASYN  : {0.0: 100, 1.0: 50}
#   ROSE    : {0.0: 100, 1.0: 50}
#
# --- Sampling strategy: {0: 100, 1: 80} ---
#   SMOTE   : {0.0: 100, 1.0: 80}
#   ADASYN  : {0.0: 100, 1.0: 80}
#   ROSE    : {0.0: 100, 1.0: 80}
#
# ======================================================================
# TESTING NaN HANDLING STRATEGIES
# ======================================================================
#
# --- NaN handling: preserve_pattern ---
# Original NaN %: 29.92%
#   SMOTE    resampled NaN %: 41.75%
#   ADASYN   resampled NaN %: 41.36%
#   ROSE     resampled NaN %: 32.30%
#
# --- NaN handling: interpolate ---
# Original NaN %: 29.92%
#   SMOTE    resampled NaN %: 22.35%
#   ADASYN   resampled NaN %: 24.09%
#   ROSE     resampled NaN %: 17.95%
#
# --- NaN handling: random_pattern ---
# Original NaN %: 29.92%
#   SMOTE    resampled NaN %: 31.20%
#   ADASYN   resampled NaN %: 33.79%
#   ROSE     resampled NaN %: 22.60%
#
# ======================================================================
# TESTING ROSE SHRINKAGE PARAMETER
# ======================================================================
#
# Original minority class mean std: 0.9555
#
# Shrinkage effects on synthetic sample dispersion:
#   shrinkage=0.0: synthetic std = 0.9300
#   shrinkage=0.5: synthetic std = 0.9967
#   shrinkage=1.0: synthetic std = 1.1875
#   shrinkage=1.5: synthetic std = 1.4538
#   shrinkage=2.0: synthetic std = 1.7615
#
# ======================================================================
# TESTING PANDAS COMPATIBILITY
# ======================================================================
#
# Input types: X=DataFrame, y=Series
#
# --- SMOTE ---
#   Output types: X=DataFrame, y=Series
#   Columns preserved: True
#   Series name preserved: True
#   Final shape: (200, 10)
#
# --- ADASYN ---
#   Output types: X=DataFrame, y=Series
#   Columns preserved: True
#   Series name preserved: True
#   Final shape: (200, 10)
#
# --- ROSE ---
#   Output types: X=DataFrame, y=Series
#   Columns preserved: True
#   Series name preserved: True
#   Final shape: (200, 10)
#
# ======================================================================
# TESTING PARALLEL PROCESSING
# ======================================================================
#
# --- SMOTE ---
#   Sequential: 0.272s, shape: (1000, 10)
#   Parallel:   2.627s, shape: (1000, 10)
#   Shapes match: True
#
# --- ADASYN ---
#   Sequential: 1.424s, shape: (996, 10)
#   Parallel:   0.331s, shape: (996, 10)
#   Shapes match: True
#
# --- ROSE ---
#   Sequential: 0.050s, shape: (1000, 10)
#   Parallel:   0.065s, shape: (1000, 10)
#   Shapes match: True
#
# ======================================================================
# TESTING DIRECT CLASS USAGE
# ======================================================================
#
# --- SMOTENaN direct ---
#   Shape: (200, 10), Distribution: {0.0: 100, 1.0: 100}
#
# --- ADASYNNaN direct ---
#   Shape: (200, 10), Distribution: {0.0: 100, 1.0: 100}
#
# --- ROSENaN direct ---
#   Shape: (200, 10), Distribution: {0.0: 100, 1.0: 100}
#
# ======================================================================
# TESTING WITH CLASSIFIERS
# ======================================================================
#
# Training set class distribution: {0.0: 350, 1.0: 35}
# Test set class distribution: {0.0: 150, 1.0: 15}
#
# --------------------------------------------------
# BASELINE - No oversampling
# --------------------------------------------------
#
# XGBoost Results:
#               precision    recall  f1-score   support
#
#     Majority       0.98      1.00      0.99       150
#     Minority       1.00      0.80      0.89        15
#
#     accuracy                           0.98       165
#    macro avg       0.99      0.90      0.94       165
# weighted avg       0.98      0.98      0.98       165
#
#
# --------------------------------------------------
# WITH SMOTE-NaN
# --------------------------------------------------
# After SMOTE: {0.0: 350, 1.0: 350}
#
# XGBoost Results:
#               precision    recall  f1-score   support
#
#     Majority       1.00      1.00      1.00       150
#     Minority       1.00      1.00      1.00        15
#
#     accuracy                           1.00       165
#    macro avg       1.00      1.00      1.00       165
# weighted avg       1.00      1.00      1.00       165
#
#
# --------------------------------------------------
# WITH ADASYN-NaN
# --------------------------------------------------
# After ADASYN: {0.0: 350, 1.0: 350}
#
# XGBoost Results:
#               precision    recall  f1-score   support
#
#     Majority       0.99      1.00      0.99       150
#     Minority       1.00      0.87      0.93        15
#
#     accuracy                           0.99       165
#    macro avg       0.99      0.93      0.96       165
# weighted avg       0.99      0.99      0.99       165
#
#
# --------------------------------------------------
# WITH ROSE-NaN
# --------------------------------------------------
# After ROSE: {0.0: 350, 1.0: 350}
#
# XGBoost Results:
#               precision    recall  f1-score   support
#
#     Majority       1.00      1.00      1.00       150
#     Minority       1.00      1.00      1.00        15
#
#     accuracy                           1.00       165
#    macro avg       1.00      1.00      1.00       165
# weighted avg       1.00      1.00      1.00       165
#
#
# ======================================================================
# PERFORMANCE COMPARISON
# ======================================================================
#
# Minority Class Recall (Sensitivity):
#   Baseline  : 0.800
#   SMOTE     : 1.000
#   ADASYN    : 0.867
#   ROSE      : 1.000
#
# Minority Class F1-Score:
#   Baseline  : 0.889
#   SMOTE     : 1.000
#   ADASYN    : 0.929
#   ROSE      : 1.000
#
# Weighted Average F1-Score:
#   Baseline  : 0.981
#   SMOTE     : 1.000
#   ADASYN    : 0.987
#   ROSE      : 1.000
#
# ======================================================================
# TESTING EDGE CASES
# ======================================================================
#
# --- Very few minority samples ---
#   SMOTE: Success, distribution = {0: 4, 1: 1}
#   ADASYN: Success, distribution = {0: 4, 1: 1}
#   ROSE: Success, distribution = {0: 4, 1: 4}
#
# --- Sample with all NaN features ---
#   SMOTE: Success, shape = (4, 3)
#   ADASYN: Success, shape = (4, 3)
#   ROSE: Success, shape = (6, 3)
#
# --- High NaN percentage (50%) ---
#   SMOTE: Success, NaN% = 60.00%
#   ADASYN: Success, NaN% = 60.29%
#   ROSE: Success, NaN% = 47.80%
#
# --- Single feature ---
#   SMOTE: Success, shape = (5, 1)
#   ADASYN: Success, shape = (5, 1)
#   ROSE: Success, shape = (8, 1)
#
# ======================================================================
# TESTING REPRODUCIBILITY
# ======================================================================
#
# --- SMOTE ---
#   Shapes match: True
#   Values match: True
#
# --- ADASYN ---
#   Shapes match: True
#   Values match: True
#
# --- ROSE ---
#   Shapes match: True
#   Values match: True
#
# ======================================================================
# TESTING REPR
# ======================================================================
#
# --- OverNaN representations ---
# OverNaN(method='SMOTE', neighbours=5, sampling_strategy='auto', nan_handling='preserve_pattern', random_state=42)
# OverNaN(method='ADASYN', neighbours=5, sampling_strategy='auto', nan_handling='preserve_pattern', beta=0.8, learning_rate=1.5, random_state=42)
# OverNaN(method='ROSE', sampling_strategy='auto', nan_handling='interpolate', shrinkage=1.5, random_state=42)
#
# ======================================================================
# USAGE DEMONSTRATION
# ======================================================================
#
#     # Example 1: Basic SMOTE usage
#     from overnan import OverNaN
#
#     oversampler = OverNaN(method='SMOTE', neighbours=5, random_state=42)
#     X_resampled, y_resampled = oversampler.fit_resample(X, y)
#
#     # Example 2: ADASYN with adaptive parameters
#     oversampler = OverNaN(
#         method='ADASYN',
#         neighbours=7,
#         beta=0.5,           # Generate fewer synthetic samples
#         learning_rate=1.5,  # Focus more on hard examples
#         nan_handling='interpolate'
#     )
#     X_resampled, y_resampled = oversampler.fit_resample(X, y)
#
#     # Example 3: ROSE - no neighbors required, good for high dimensions
#     oversampler = OverNaN(
#         method='ROSE',
#         shrinkage=1.0,      # Standard Silverman bandwidth
#         nan_handling='preserve_pattern',
#         n_jobs=-1           # Use all CPU cores
#     )
#     X_resampled, y_resampled = oversampler.fit_resample(X, y)
#
#     # Example 4: ROSE with tighter samples (closer to originals)
#     oversampler = OverNaN(
#         method='ROSE',
#         shrinkage=0.5,      # Samples closer to seeds
#         random_state=42
#     )
#     X_resampled, y_resampled = oversampler.fit_resample(X, y)
#
#     # Example 5: Direct class usage
#     from overnan import SMOTENaN, ADASYNNaN, ROSENaN
#
#     smote = SMOTENaN(neighbours=5, nan_handling='preserve_pattern')
#     adasyn = ADASYNNaN(neighbours=5, beta=1.0, learning_rate=1.0)
#     rose = ROSENaN(shrinkage=1.0, nan_handling='interpolate')
#
#     # Example 6: Sampling strategy options
#     oversampler = OverNaN(
#         method='SMOTE',
#         sampling_strategy='auto',  # Balance all minority classes
#         # OR sampling_strategy=0.8,  # 80% of majority
#         # OR sampling_strategy={0: 100, 1: 80},  # Exact counts
#     )
#
#     # Example 7: Integration with XGBoost (handles NaN naturally)
#     from sklearn.model_selection import train_test_split
#     import xgboost as xgb
#
#     X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y)
#
#     oversampler = OverNaN(method='ROSE', random_state=42)
#     X_train_balanced, y_train_balanced = oversampler.fit_resample(X_train, y_train)
#
#     model = xgb.XGBClassifier(random_state=42)
#     model.fit(X_train_balanced, y_train_balanced)
#     accuracy = model.score(X_test, y_test)
#
#
# ######################################################################
# #                     All Tests Completed!                     #
# ######################################################################

# %%
"""
OverNaN Benchmark Suite
=======================

Benchmarks OverNaN oversampling methods (SMOTE, ADASYN, ROSE) on publicly
available OpenML datasets with naturally occurring missing values.

Datasets are selected to be:
- Classification tasks with class imbalance
- Containing natural missing values (not artificially introduced)

Metrics reported:
- Balanced Accuracy
- F1-Score (macro and minority class)
- ROC-AUC
- Geometric Mean (G-Mean)

References
----------
OpenML: https://www.openml.org/
Vanschoren, J., van Rijn, J.N., Bischl, B., Torgo, L. (2014).
OpenML: Networked Science in Machine Learning. SIGKDD Explorations, 15(2), 49-60.
DOI: 10.1145/2641190.2641198
"""

# %run -i OverNaN_bench.py
# Out:
# ======================================================================
# OverNaN Benchmark Suite
# ======================================================================
# Datasets: 5
# Methods: Baseline, SMOTENaN, ADASYNNaN, ROSENaN
# Cross-validation: 5-fold stratified
# Random state: 42
# ======================================================================
#
# [1/5] Processing labor...
#   Loading labor (OpenML ID: 4)...
#
#   Dataset: labor (Labor/Economics)
#     Samples: 57, Features: 16, Classes: 2
#     Class distribution: {0: 20, 1: 37}
#     Imbalance ratio: 1.85
#     Missing values: 326 (35.75%)
#     Features with NaN: 16, Samples with NaN: 56
#     Running Baseline... done (0.1s) - Bal.Acc: 0.911
#     Running SMOTENaN... done (0.4s) - Bal.Acc: 0.896
#     Running ADASYNNaN... done (0.5s) - Bal.Acc: 0.868
#     Running ROSENaN... done (0.3s) - Bal.Acc: 0.911
#
# [2/5] Processing cylinder-bands...
#   Loading cylinder-bands (OpenML ID: 6332)...
#
#   Dataset: cylinder-bands (Engineering)
#     Samples: 540, Features: 37, Classes: 2
#     Class distribution: {0: 228, 1: 312}
#     Imbalance ratio: 1.37
#     Missing values: 999 (5.00%)
#     Features with NaN: 28, Samples with NaN: 263
#     Running Baseline... done (0.2s) - Bal.Acc: 0.796
#     Running SMOTENaN... done (2.1s) - Bal.Acc: 0.813
#     Running ADASYNNaN... done (10.5s) - Bal.Acc: 0.820
#     Running ROSENaN... done (0.6s) - Bal.Acc: 0.823
#
# [3/5] Processing Titanic...
#   Loading Titanic (OpenML ID: 40945)...
#
#   Dataset: Titanic (Transportation/Historical)
#     Samples: 1309, Features: 13, Classes: 2
#     Class distribution: {0: 809, 1: 500}
#     Imbalance ratio: 1.62
#     Missing values: 3855 (22.65%)
#     Features with NaN: 7, Samples with NaN: 1309
#     Running Baseline... done (0.2s) - Bal.Acc: 0.965
#     Running SMOTENaN... done (11.7s) - Bal.Acc: 0.965
#     Running ADASYNNaN... done (56.6s) - Bal.Acc: 0.961
#     Running ROSENaN... done (0.5s) - Bal.Acc: 0.967
#
# [4/5] Processing soybean...
#   Loading soybean (OpenML ID: 1023)...
#
#   Dataset: soybean (Environmental Science)
#     Samples: 683, Features: 35, Classes: 2
#     Class distribution: {0: 591, 1: 92}
#     Imbalance ratio: 6.42
#     Missing values: 2337 (9.78%)
#     Features with NaN: 34, Samples with NaN: 121
#     Running Baseline... done (0.2s) - Bal.Acc: 0.930
#     Running SMOTENaN... done (1.5s) - Bal.Acc: 0.948
#     Running ADASYNNaN... done (6.1s) - Bal.Acc: 0.940
#     Running ROSENaN... done (0.7s) - Bal.Acc: 0.950
#
# [5/5] Processing car-evaluation...
#   Loading car-evaluation (OpenML ID: 1017)...
#
#   Dataset: car-evaluation (Consumer/Automotive)
#     Samples: 452, Features: 279, Classes: 2
#     Class distribution: {0: 207, 1: 245}
#     Imbalance ratio: 1.18
#     Missing values: 408 (0.32%)
#     Features with NaN: 5, Samples with NaN: 384
#     Running Baseline... done (0.7s) - Bal.Acc: 0.817
#     Running SMOTENaN... done (2.0s) - Bal.Acc: 0.808
#     Running ADASYNNaN... done (8.8s) - Bal.Acc: 0.817
#     Running ROSENaN... done (1.3s) - Bal.Acc: 0.832
#
# ======================================================================
# BENCHMARK SUMMARY
# ======================================================================
#
# labor (NaN: 35.7%, IR: 1.9)
# ------------------------------------------------------------
# Method          Bal.Acc   F1-Macro     F1-Min     G-Mean    ROC-AUC
# ------------------------------------------------------------
# Baseline     0.911±0.077 0.920±0.074 0.893±0.096 0.907±0.080 0.959±0.056
# SMOTENaN     0.896±0.065 0.901±0.062 0.871±0.080 0.892±0.067 0.965±0.055
# ADASYNNaN    0.868±0.085 0.866±0.094 0.836±0.107 0.862±0.085 0.986±0.029
# ROSENaN      0.911±0.077 0.920±0.074 0.893±0.096 0.907±0.080 0.971±0.057
#
# cylinder-bands (NaN: 5.0%, IR: 1.4)
# ------------------------------------------------------------
# Method          Bal.Acc   F1-Macro     F1-Min     G-Mean    ROC-AUC
# ------------------------------------------------------------
# Baseline     0.796±0.034 0.799±0.034 0.754±0.053 0.787±0.045 0.890±0.015
# SMOTENaN     0.813±0.039 0.817±0.040 0.777±0.057 0.806±0.048 0.895±0.022
# ADASYNNaN    0.820±0.034 0.823±0.034 0.786±0.047 0.814±0.040 0.902±0.015
# ROSENaN      0.823±0.042 0.827±0.043 0.791±0.055 0.818±0.047 0.908±0.021
#
# Titanic (NaN: 22.7%, IR: 1.6)
# ------------------------------------------------------------
# Method          Bal.Acc   F1-Macro     F1-Min     G-Mean    ROC-AUC
# ------------------------------------------------------------
# Baseline     0.965±0.011 0.967±0.010 0.959±0.012 0.965±0.012 0.993±0.003
# SMOTENaN     0.965±0.008 0.963±0.005 0.954±0.006 0.964±0.008 0.994±0.003
# ADASYNNaN    0.961±0.008 0.960±0.005 0.951±0.006 0.961±0.008 0.993±0.004
# ROSENaN      0.967±0.015 0.968±0.012 0.960±0.016 0.967±0.015 0.995±0.003
#
# soybean (NaN: 9.8%, IR: 6.4)
# ------------------------------------------------------------
# Method          Bal.Acc   F1-Macro     F1-Min     G-Mean    ROC-AUC
# ------------------------------------------------------------
# Baseline     0.930±0.038 0.944±0.028 0.903±0.050 0.927±0.041 0.993±0.005
# SMOTENaN     0.948±0.047 0.946±0.042 0.907±0.073 0.946±0.050 0.994±0.005
# ADASYNNaN    0.940±0.037 0.948±0.032 0.910±0.057 0.938±0.039 0.993±0.006
# ROSENaN      0.950±0.040 0.952±0.036 0.917±0.063 0.948±0.042 0.994±0.004
#
# car-evaluation (NaN: 0.3%, IR: 1.2)
# ------------------------------------------------------------
# Method          Bal.Acc   F1-Macro     F1-Min     G-Mean    ROC-AUC
# ------------------------------------------------------------
# Baseline     0.817±0.060 0.817±0.059 0.794±0.073 0.813±0.062 0.881±0.072
# SMOTENaN     0.808±0.062 0.808±0.062 0.784±0.078 0.803±0.065 0.879±0.065
# ADASYNNaN    0.817±0.060 0.817±0.059 0.794±0.073 0.813±0.062 0.881±0.072
# ROSENaN      0.832±0.063 0.833±0.063 0.812±0.076 0.829±0.065 0.898±0.051
#
# ======================================================================
# OVERALL AVERAGE ACROSS DATASETS
# ======================================================================
#
# Method          Bal.Acc   F1-Macro     F1-Min     G-Mean    ROC-AUC    Time(s)
# ------------------------------------------------------------------------
# Baseline         0.8836     0.8893     0.8604     0.8798     0.9432        0.3
# SMOTENaN         0.8860     0.8869     0.8584     0.8822     0.9455        3.5
# ADASYNNaN        0.8811     0.8830     0.8555     0.8775     0.9509       16.5
# ROSENaN          0.8967     0.8999     0.8746     0.8937     0.9533        0.7
#
# ----------------------------------------------------------------------
# IMPROVEMENT OVER BASELINE (percentage points)
# ----------------------------------------------------------------------
#
# Method          Bal.Acc   F1-Macro     F1-Min     G-Mean
# ----------------------------------------------------
# SMOTENaN          +0.24      -0.24      -0.20      +0.24
# ADASYNNaN         -0.25      -0.63      -0.49      -0.23
# ROSENaN           +1.31      +1.06      +1.42      +1.39
#
# Results saved to: overnan_benchmark_results.csv
#
# ======================================================================
# COMPARISON: OverNaN vs Impute-Then-Oversample
# ======================================================================
#   Loading anneal (OpenML ID: 989)...
#
#   Dataset: anneal (Materials Science)
#     Samples: 898, Features: 38, Classes: 2
#     Class distribution: {0: 214, 1: 684}
#     Imbalance ratio: 3.20
#     Missing values: 22175 (64.98%)
#     Features with NaN: 29, Samples with NaN: 898
#     Running Baseline... Bal.Acc: 0.985
#     Running Impute+SMOTE... Bal.Acc: 0.991
#     Running Impute+ADASYN... Bal.Acc: 0.989
#     Running Impute+ROSE... Bal.Acc: 0.985
#     Running OverNaN-SMOTE... Bal.Acc: 0.989
#     Running OverNaN-ADASYN... Bal.Acc: 0.990
#     Running OverNaN-ROSE... Bal.Acc: 0.986
#
#   Comparison Results (anneal dataset):
#   ------------------------------------------------------------
#   Approach                     Bal.Acc        F1-Macro
#   ------------------------------------------------------------
#   Baseline                 0.985±0.005     0.986±0.003
#   Impute+SMOTE             0.991±0.007     0.988±0.009
#   Impute+ADASYN            0.989±0.004     0.986±0.006
#   Impute+ROSE              0.985±0.012     0.986±0.009
#   OverNaN-SMOTE            0.989±0.008     0.986±0.007
#   OverNaN-ADASYN           0.990±0.009     0.989±0.008
#   OverNaN-ROSE             0.986±0.007     0.983±0.006
#
# ======================================================================
# Benchmark completed!
# ======================================================================
